# %% [markdown]
# <html>
# <head>
# <H1><FONT COLOR="navy">Análisis Comparativo y Predicción de Precios de Etherium y Bitcoin mediante Modelos de Series de Tiempo</FONT>
# </H1>
# </head>
# <body>
# <p>
# <sub><H2>
# Reporte Número 1:
# </H2></sub>
# En este proyecto, tenemos la intención de emplear la estadística descriptiva, métodos supervisados explicativos y modelos de series de tiempo para analizar el comportamiento del precio de mercado de Ethereum. Además, realizaremos una comparación con Bitcoin y buscaremos predecir los precios futuros de esta criptomoneda. Para llevar a cabo este análisis, utilizaremos los   datos públicos obtenidos de Google Finance.
# <p><sub><H3>Autor:</H3></sub>Juan Esteban Orduz Chavez
# <p><sub><H3>Asesor Principal:</H3></sub>xd
# <p><sub><H2>Introducción.</H2></sub>
# Durante los últimos años, se ha popularizado el término "criptomoneda". Estas criptomonedas son un tipo de moneda digital que utilizan técnicas de criptografía para asegurar las transacciones y controlar la creación de nuevas unidades. Estas técnicas criptográficas funcionan en base a una red descentralizada basada en la tecnología blockchain, lo que permite transacciones seguras y transparentes sin necesidad de intermediarios como bancos.Como cualquier tipo de producto, estas obtienen valor a partir del deseo de poseerlas que tienen las personas. Por lo mismo, el precio de mercado de estas criptomonedas dependerá de la oferta y la demanda de las mismas. Así pues, existe la posibilidad de obtener ganancias comprando o vendiendo criptomonedas, dependiendo de cómo varíe el precio en el futuro.
# <p>
# Debido a este último punto, es de gran importancia para distintos agentes de inversión poder predecir, con un margen de error bajo, el precio que tendrán las criptomonedas. En el caso particular de este proyecto, se enfoca en las criptomonedas Ethereum y Bitcoin, especialmente en la primera. El objetivo de este proyecto es llevar a cabo un estudio descriptivo de los precios de Ethereum y posteriormente modelar una predicción para su precio en el futuro.
# <p><sub><H2>Descripción del Problema.</H2></sub>
# Abordaremos el desafío de comprender y pronosticar el comportamiento del precio de mercado de Ethereum, una criptomoneda de gran relevancia. Para lograrlo, emplearemos un enfoque integral que combina técnicas de estadística descriptiva, métodos supervisados explicativos y posiblemente modelos de series de tiempo.
# <p><sub><H2>Fuentes de Datos.</H2></sub>
# Los datos se obtendran mediante google finance de donde obtendremos archivos CVS y son de naturaleza pública, comparto las las páginas de ambos, tanto Etherium: <a href='https://www.google.com/finance/quote/ETH-USD?hl=es&window=MAX'>Valor Historico de Precios Etherium</a>, como para Bitcoin: <a href='https://www.google.com/finance/quote/BTC-USD?hl=es&window=MAX'>Valor Historico de Precios Bitcoin</a>. Utilizando el comando en excel GOOGLEFINANCE().Estos datos son:<br>
# <UL TYPE=SQUARE>
# <LI>date: sin ellas no serian series de tiempo.
# <LI>open: precios con los que inicia el dia la criptomoneda.
# <LI>close: precios con los que termina el día la criptomoneda.
# <LI>high: el valor más alto a lo largo del día.
# <LI>low: el valor más bajo a lo largo del día.
# <LI>Volume: se refiere a la cantidad de transacciones de la criptomoneda entre compradores y vendedores a lo largo del día.
# </UL>
# <p><sub><H2>Proceso ETL.</H2></sub>
# El primer paso para llevar a cabo esto sera tomar los datos históricos de los precios de mercado en dólares de Ethereum y Bitcoin desde el año 2016 hasta la actualidad. Obtendremos estos datos a partir de la fuente pública de Google Finance en formato CSV, los transformaremos en SQL Server de Microsoft (debido a sus facilidades) y luego los extraeremos en JupyterLab como series de tiempo.
# <p><sub><H2>Exploración de Datos.</H2></sub>
# En el segundo paso, llevaremos a cabo un estudio preliminar de estadística descriptiva. En este análisis, obtendremos medidas de tendencia central como la media, y evaluaremos la variabilidad a través de la varianza y la entropía. Además, presentaremos estos resultados de manera visual mediante diagramas de densidad. También exploraremos la relación entre los datos de Ethereum y Bitcoin, estudiando la covarianza y el coeficiente de Pearson.
# <p><sub><H2>Técnicas de Modelación Propuestas</H2></sub>
# Utilizaremos el método de prueba Chi cuadrado de Pearson para probar si el valor de Etherium esta realmente relacionado con Bitcoin, también intentaremos construir un Modelo Supervisado Explicativo de Regresión Polinomial, específicamente, para los datos de precio de Etherium.<br>
# En etapas posteriores, nos embarcaremos en la creación de un modelo SARIMA utilizando el módulo de StatsModels. Para lograr este objetivo, iniciaremos con la realización de una prueba de Dickey-Fuller Aumentada en Python, haciendo uso de dicha librería. Esta prueba se ejecutará mediante la función adfuller, cuyo propósito es verificar la hipótesis de si es más apropiado considerar la serie como estacionaria o no estacionaria.<br>
# A continuación, procederemos a convertir las series de tiempo en un formato estacionario. Realizaremos las transformaciones Box-Cox necesarias y las diferenciaciones correspondientes para alcanzar este objetivo. Una vez completadas estas etapas, llevaremos a cabo un análisis exhaustivo de los residuos obtenidos.<br>
# Finalmente, culminaremos este proceso mediante la realización de predicciones de los precios de Ethereum utilizando el modelo SARIMA previamente construido. Este enfoque integral nos permitirá explorar y entender los patrones intrínsecos en los datos de Ethereum y, en última instancia, proyectar posibles escenarios futuros con mayor precisión.
# <p><sub><H2>Conocimientos Requeridos para el Proyecto.</H2></sub>
# <UL TYPE=SQUARE>
# <LI>Desarrollo de procesos ETL
# <LI>Estadística Descriptiva e Inferencial
# <LI>Desarrollo de módelos supervisados explicativo
# <LI>Econometría
# <LI>Programación orientada a objetos
# <LI>Desarrollo de módelos supervisados predictivos
# <LI>Analísis de Seríes Temporales, en especifico módelo ARIMA y SARIMA
# <LI>Excel: (Básico)
# <LI>SQL Microsoft server: (Básico)
# <LI>Python: (Intermedio)
# <LI>JupyterLab: (Intermedio)
# </UL>
# <p><sub><H2>Resultados Esperados.</sub></H2>
# Esperamos disernir si realmente existe una correlación real entre el cambio de precios de Bitcoin y Etherium, además de encontrar una función de precio para Etherium a travez de la regreción polinomial.<br>
# Si es posible tambien diseñar un modelo más preciso a travez del análisis de series temporales, como por ejemplo el ya mencionado modelo SARIMA para el caso particular de Etherium.
# <p><sub><H2>Tiempo de Desarrollo Esperado.</sub></H2>
# Esperamos completar como mínimo la primera parte en las siguientes 4 semanas, en cuanto a la segunda de ser posible realizarse en 2 semanas, para realizar la totalidad del proyecto en 6 semanas.
# </body>
# </html>
